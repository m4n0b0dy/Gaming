# %%
from vg_data_types import *

# %%
i = game_img('test')
i.load('imgs/img_ZweiII_-_PC.bmp', pull_file=True)
i.data
# Out:
# Loaded file into memory
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=353x500 at 0x7FCC8B063780>

# %%
t = game_txt('test')
t.load('txts/txt_ZweiII_-_PC.json', True)
t.data
# Out:
# Loaded file into memory
# ''
